# %% [markdown]
# 1) instale a biblioteca eodag para consultar as cenas que estão em sua área de estudo (Obs: só é necessário instalar uma vez, depois comente a linha)

# %%
# !pip install eodag

# %% [markdown]
# 2. Importe as bibliotecas e defina os limites máximos e mínimos (lat, lon) da sua área de estudo

# %%
#Importando bibliotecas necessárias
import os
from eodag import EODataAccessGateway, setup_logging
import datetime
from dateutil import parser
import time
import requests
from tqdm import tqdm
import sys

#Criando coordenadas da minha área de estudo
coords = [-44.06262124827551, -23.108686697869885, -43.59295572093176, -22.89505336946246] #Insera nesta ordem: lonmin, latmin, lonmax, latmax

# %% [markdown]
# 3. Looping para procurar as cenas que estão dentra da geometria para um range de data específico

# %%
# Parâmetros iniciais
start_date = '2021-04-01'
end_date = '2021-05-01'
all_results = []

while parser.parse(start_date) < parser.parse(end_date):
    # Fazer a busca
    search_results = dag.search(
        productType='S3_EFR',
        geom={'lonmin': coords[0], 'latmin': coords[1], 'lonmax': coords[2], 'latmax': [3]},
        start=start_date,
        end=end_date,
        provider='creodias',
    )

    if not search_results:
        print("Nenhum novo resultado encontrado. Encerrando...")
        break

    # Armazena os resultados encontrados
    all_results.extend(search_results)

    # Obtém a última data retornada
    last_entry = search_results[-1]
    last_date_str = str(last_entry).split("id=")[1][16:24]  # Ajuste conforme necessário

    # Exibir para conferir o formato
    print(f"Data extraída: {last_date_str}")

    try:
        # Tentar converter a data
        last_date = datetime.datetime.strptime(last_date_str, '%y%m%d')  # Formato esperado: ano (2 dígitos), mês e dia
    except ValueError:
        # Ajuste caso o formato seja diferente (por exemplo, com ano completo)
        last_date = datetime.datetime.strptime(last_date_str, '%Y%m%d')  # Ajuste para o formato completo do ano

    # Define o próximo início um dia após a última data
    start_date = (last_date + datetime.timedelta(days=1)).strftime('%Y-%m-%d')

    print(f"Nova busca a partir de {start_date}")

print(f"Total de produtos encontrados: {len(all_results)}")
# Out:
# Data extraída: 20160517
# Nova busca a partir de 2016-05-18
# Data extraída: 20160609
# Nova busca a partir de 2016-06-10
# Data extraída: 20160629
# Nova busca a partir de 2016-06-30
# Data extraída: 20160721
# Nova busca a partir de 2016-07-22
# Data extraída: 20160810
# Nova busca a partir de 2016-08-11
# Data extraída: 20160829
# Nova busca a partir de 2016-08-30
# Data extraída: 20160918
# Nova busca a partir de 2016-09-19
# Data extraída: 20161010
# Nova busca a partir de 2016-10-11
# Data extraída: 20161031
# Nova busca a partir de 2016-11-01
# Data extraída: 20161121
# Nova busca a partir de 2016-11-22
# Data extraída: 20161211
# Nova busca a partir de 2016-12-12
# Data extraída: 20161230
# Nova busca a partir de 2016-12-31
# Data extraída: 20170110
# Nova busca a partir de 2017-01-11
# Data extraída: 20170120
# Nova busca a partir de 2017-01-21
# Data extraída: 20170130
# Nova busca a partir de 2017-01-31
# Data extraída: 20170210
# Nova busca a partir de 2017-02-11
# Data extraída: 20170220
# Nova busca a partir de 2017-02-21
# Data extraída: 20170302
# Nova busca a partir de 2017-03-03
# Data extraída: 20170313
# Nova busca a partir de 2017-03-14
# Data extraída: 20170323
# Nova busca a partir de 2017-03-24
# Data extraída: 20170403
# Nova busca a partir de 2017-04-04
# Data extraída: 20170413
# Nova busca a partir de 2017-04-14
# Data extraída: 20170424
# Nova busca a partir de 2017-04-25
# Data extraída: 20170504
# Nova busca a partir de 2017-05-05
# Data extraída: 20170514
# Nova busca a partir de 2017-05-15
# Data extraída: 20170526
# Nova busca a partir de 2017-05-27
# Data extraída: 20170606
# Nova busca a partir de 2017-06-07
# Data extraída: 20170619
# Nova busca a partir de 2017-06-20
# Data extraída: 20170629
# Nova busca a partir de 2017-06-30
# Data extraída: 20170709
# Nova busca a partir de 2017-07-10
# Data extraída: 20170719
# Nova busca a partir de 2017-07-20
# Data extraída: 20170730
# Nova busca a partir de 2017-07-31
# Data extraída: 20170810
# Nova busca a partir de 2017-08-11
# Data extraída: 20170820
# Nova busca a partir de 2017-08-21
# Data extraída: 20170830
# Nova busca a partir de 2017-08-31
# Data extraída: 20170910
# Nova busca a partir de 2017-09-11
# Data extraída: 20170920
# Nova busca a partir de 2017-09-21
# Data extraída: 20170930
# Nova busca a partir de 2017-10-01
# Data extraída: 20171011
# Nova busca a partir de 2017-10-12
# Data extraída: 20171021
# Nova busca a partir de 2017-10-22
# Data extraída: 20171107
# Nova busca a partir de 2017-11-08
# Data extraída: 20171120
# Nova busca a partir de 2017-11-21
# Data extraída: 20171210
# Nova busca a partir de 2017-12-11
# Data extraída: 20171231
# Nova busca a partir de 2018-01-01
# Data extraída: 20180123
# Nova busca a partir de 2018-01-24
# Data extraída: 20180213
# Nova busca a partir de 2018-02-14
# Data extraída: 20180307
# Nova busca a partir de 2018-03-08
# Data extraída: 20180328
# Nova busca a partir de 2018-03-29
# Data extraída: 20180420
# Nova busca a partir de 2018-04-21
# Data extraída: 20180512
# Nova busca a partir de 2018-05-13
# Data extraída: 20180524
# Nova busca a partir de 2018-05-25
# Data extraída: 20180605
# Nova busca a partir de 2018-06-06
# Data extraída: 20180615
# Nova busca a partir de 2018-06-16
# Data extraída: 20180627
# Nova busca a partir de 2018-06-28
# Data extraída: 20180708
# Nova busca a partir de 2018-07-09
# Data extraída: 20180720
# Nova busca a partir de 2018-07-21
# Data extraída: 20180731
# Nova busca a partir de 2018-08-01
# Data extraída: 20180810
# Nova busca a partir de 2018-08-11
# Data extraída: 20180820
# Nova busca a partir de 2018-08-21
# Data extraída: 20180831
# Nova busca a partir de 2018-09-01
# Data extraída: 20180910
# Nova busca a partir de 2018-09-11
# Data extraída: 20180920
# Nova busca a partir de 2018-09-21
# Data extraída: 20181001
# Nova busca a partir de 2018-10-02
# Data extraída: 20181011
# Nova busca a partir de 2018-10-12
# Data extraída: 20181021
# Nova busca a partir de 2018-10-22
# Data extraída: 20181101
# Nova busca a partir de 2018-11-02
# Data extraída: 20181112
# Nova busca a partir de 2018-11-13
# Data extraída: 20181123
# Nova busca a partir de 2018-11-24
# Data extraída: 20181203
# Nova busca a partir de 2018-12-04
# Data extraída: 20181212
# Nova busca a partir de 2018-12-13
# Data extraída: 20181220
# Nova busca a partir de 2018-12-21
# Data extraída: 20181227
# Nova busca a partir de 2018-12-28
# Data extraída: 20190104
# Nova busca a partir de 2019-01-05
# Data extraída: 20190111
# Nova busca a partir de 2019-01-12
# Data extraída: 20190119
# Nova busca a partir de 2019-01-20
# Data extraída: 20190127
# Nova busca a partir de 2019-01-28
# Data extraída: 20190204
# Nova busca a partir de 2019-02-05
# Data extraída: 20190212
# Nova busca a partir de 2019-02-13
# Data extraída: 20190219
# Nova busca a partir de 2019-02-20
# Data extraída: 20190227
# Nova busca a partir de 2019-02-28
# Data extraída: 20190306
# Nova busca a partir de 2019-03-07
# Data extraída: 20190314
# Nova busca a partir de 2019-03-15
# Data extraída: 20190322
# Nova busca a partir de 2019-03-23
# Data extraída: 20190330
# Nova busca a partir de 2019-03-31
# Data extraída: 20190407
# Nova busca a partir de 2019-04-08
# Data extraída: 20190414
# Nova busca a partir de 2019-04-15
# Data extraída: 20190422
# Nova busca a partir de 2019-04-23
# Data extraída: 20190429
# Nova busca a partir de 2019-04-30
# Data extraída: 20190507
# Nova busca a partir de 2019-05-08
# Data extraída: 20190515
# Nova busca a partir de 2019-05-16
# Data extraída: 20190523
# Nova busca a partir de 2019-05-24
# Data extraída: 20190531
# Nova busca a partir de 2019-06-01
# Data extraída: 20190607
# Nova busca a partir de 2019-06-08
# Data extraída: 20190615
# Nova busca a partir de 2019-06-16
# Data extraída: 20190622
# Nova busca a partir de 2019-06-23
# Data extraída: 20190630
# Nova busca a partir de 2019-07-01
# Data extraída: 20190708
# Nova busca a partir de 2019-07-09
# Data extraída: 20190716
# Nova busca a partir de 2019-07-17
# Data extraída: 20190724
# Nova busca a partir de 2019-07-25
# Data extraída: 20190731
# Nova busca a partir de 2019-08-01
# Data extraída: 20190808
# Nova busca a partir de 2019-08-09
# Data extraída: 20190815
# Nova busca a partir de 2019-08-16
# Data extraída: 20190823
# Nova busca a partir de 2019-08-24
# Data extraída: 20190831
# Nova busca a partir de 2019-09-01
# Data extraída: 20190908
# Nova busca a partir de 2019-09-09
# Data extraída: 20190916
# Nova busca a partir de 2019-09-17
# Data extraída: 20190923
# Nova busca a partir de 2019-09-24
# Data extraída: 20191001
# Nova busca a partir de 2019-10-02
# Data extraída: 20191008
# Nova busca a partir de 2019-10-09
# Data extraída: 20191016
# Nova busca a partir de 2019-10-17
# Data extraída: 20191024
# Nova busca a partir de 2019-10-25
# Data extraída: 20191101
# Nova busca a partir de 2019-11-02
# Data extraída: 20191112
# Nova busca a partir de 2019-11-13
# Data extraída: 20191122
# Nova busca a partir de 2019-11-23
# Data extraída: 20191203
# Nova busca a partir de 2019-12-04
# Data extraída: 20191214
# Nova busca a partir de 2019-12-15
# Data extraída: 20191224
# Nova busca a partir de 2019-12-25
# Data extraída: 20200103
# Nova busca a partir de 2020-01-04
# Data extraída: 20200113
# Nova busca a partir de 2020-01-14
# Data extraída: 20200123
# Nova busca a partir de 2020-01-24
# Data extraída: 20200203
# Nova busca a partir de 2020-02-04
# Data extraída: 20200214
# Nova busca a partir de 2020-02-15
# Data extraída: 20200225
# Nova busca a partir de 2020-02-26
# Data extraída: 20200306
# Nova busca a partir de 2020-03-07
# Data extraída: 20200316
# Nova busca a partir de 2020-03-17
# Data extraída: 20200327
# Nova busca a partir de 2020-03-28
# Data extraída: 20200406
# Nova busca a partir de 2020-04-07
# Data extraída: 20200416
# Nova busca a partir de 2020-04-17
# Data extraída: 20200427
# Nova busca a partir de 2020-04-28
# Data extraída: 20200507
# Nova busca a partir de 2020-05-08
# Data extraída: 20200517
# Nova busca a partir de 2020-05-18
# Data extraída: 20200527
# Nova busca a partir de 2020-05-28
# Data extraída: 20200606
# Nova busca a partir de 2020-06-07
# Data extraída: 20200617
# Nova busca a partir de 2020-06-18
# Data extraída: 20200628
# Nova busca a partir de 2020-06-29
# Data extraída: 20200709
# Nova busca a partir de 2020-07-10
# Data extraída: 20200719
# Nova busca a partir de 2020-07-20
# Data extraída: 20200729
# Nova busca a partir de 2020-07-30
# Data extraída: 20200809
# Nova busca a partir de 2020-08-10
# Data extraída: 20200819
# Nova busca a partir de 2020-08-20
# Data extraída: 20200829
# Nova busca a partir de 2020-08-30
# Data extraída: 20200909
# Nova busca a partir de 2020-09-10
# Data extraída: 20200919
# Nova busca a partir de 2020-09-20
# Data extraída: 20200929
# Nova busca a partir de 2020-09-30
# Data extraída: 20201009
# Nova busca a partir de 2020-10-10
# Data extraída: 20201019
# Nova busca a partir de 2020-10-20
# Data extraída: 20201030
# Nova busca a partir de 2020-10-31
# Data extraída: 20201110
# Nova busca a partir de 2020-11-11
# Data extraída: 20201121
# Nova busca a partir de 2020-11-22
# Data extraída: 20201201
# Nova busca a partir de 2020-12-02
# Data extraída: 20201211
# Nova busca a partir de 2020-12-12
# Data extraída: 20201222
# Nova busca a partir de 2020-12-23
# Data extraída: 20210101
# Nova busca a partir de 2021-01-02
# Data extraída: 20210111
# Nova busca a partir de 2021-01-12
# Data extraída: 20210122
# Nova busca a partir de 2021-01-23
# Data extraída: 20210201
# Nova busca a partir de 2021-02-02
# Data extraída: 20210211
# Nova busca a partir de 2021-02-12
# Data extraída: 20210221
# Nova busca a partir de 2021-02-22
# Data extraída: 20210303
# Nova busca a partir de 2021-03-04
# Data extraída: 20210314
# Nova busca a partir de 2021-03-15
# Data extraída: 20210325
# Nova busca a partir de 2021-03-26
# Data extraída: 20210405
# Nova busca a partir de 2021-04-06
# Data extraída: 20210415
# Nova busca a partir de 2021-04-16
# Data extraída: 20210425
# Nova busca a partir de 2021-04-26
# Data extraída: 20210506
# Nova busca a partir de 2021-05-07
# Data extraída: 20210516
# Nova busca a partir de 2021-05-17
# Data extraída: 20210526
# Nova busca a partir de 2021-05-27
# Data extraída: 20210606
# Nova busca a partir de 2021-06-07
# Data extraída: 20210616
# Nova busca a partir de 2021-06-17
# Data extraída: 20210626
# Nova busca a partir de 2021-06-27
# Data extraída: 20210706
# Nova busca a partir de 2021-07-07
# Data extraída: 20210716
# Nova busca a partir de 2021-07-17
# Data extraída: 20210727
# Nova busca a partir de 2021-07-28
# Data extraída: 20210807
# Nova busca a partir de 2021-08-08
# Data extraída: 20210818
# Nova busca a partir de 2021-08-19
# Data extraída: 20210828
# Nova busca a partir de 2021-08-29
# Data extraída: 20210907
# Nova busca a partir de 2021-09-08
# Data extraída: 20210918
# Nova busca a partir de 2021-09-19
# Data extraída: 20210928
# Nova busca a partir de 2021-09-29
# Data extraída: 20211008
# Nova busca a partir de 2021-10-09
# Data extraída: 20211019
# Nova busca a partir de 2021-10-20
# Data extraída: 20211029
# Nova busca a partir de 2021-10-30
# Data extraída: 20211108
# Nova busca a partir de 2021-11-09
# Data extraída: 20211118
# Nova busca a partir de 2021-11-19
# Data extraída: 20211128
# Nova busca a partir de 2021-11-29
# Data extraída: 20211209
# Nova busca a partir de 2021-12-10
# Data extraída: 20211220
# Nova busca a partir de 2021-12-21
# Data extraída: 20211231
# Nova busca a partir de 2022-01-01
# Data extraída: 20220110
# Nova busca a partir de 2022-01-11
# Data extraída: 20220120
# Nova busca a partir de 2022-01-21
# Data extraída: 20220131
# Nova busca a partir de 2022-02-01
# Data extraída: 20220210
# Nova busca a partir de 2022-02-11
# Data extraída: 20220220
# Nova busca a partir de 2022-02-21
# Data extraída: 20220303
# Nova busca a partir de 2022-03-04
# Data extraída: 20220313
# Nova busca a partir de 2022-03-14
# Data extraída: 20220323
# Nova busca a partir de 2022-03-24
# Data extraída: 20220402
# Nova busca a partir de 2022-04-03
# Data extraída: 20220412
# Nova busca a partir de 2022-04-13
# Data extraída: 20220423
# Nova busca a partir de 2022-04-24
# Data extraída: 20220504
# Nova busca a partir de 2022-05-05
# Data extraída: 20220515
# Nova busca a partir de 2022-05-16
# Data extraída: 20220525
# Nova busca a partir de 2022-05-26
# Data extraída: 20220604
# Nova busca a partir de 2022-06-05
# Data extraída: 20220615
# Nova busca a partir de 2022-06-16
# Data extraída: 20220625
# Nova busca a partir de 2022-06-26
# Data extraída: 20220705
# Nova busca a partir de 2022-07-06
# Data extraída: 20220716
# Nova busca a partir de 2022-07-17
# Data extraída: 20220726
# Nova busca a partir de 2022-07-27
# Data extraída: 20220805
# Nova busca a partir de 2022-08-06
# Data extraída: 20220815
# Nova busca a partir de 2022-08-16
# Data extraída: 20220825
# Nova busca a partir de 2022-08-26
# Data extraída: 20220905
# Nova busca a partir de 2022-09-06
# Data extraída: 20220916
# Nova busca a partir de 2022-09-17
# Data extraída: 20220927
# Nova busca a partir de 2022-09-28
# Data extraída: 20221007
# Nova busca a partir de 2022-10-08
# Data extraída: 20221017
# Nova busca a partir de 2022-10-18
# Data extraída: 20221028
# Nova busca a partir de 2022-10-29
# Data extraída: 20221107
# Nova busca a partir de 2022-11-08
# Data extraída: 20221117
# Nova busca a partir de 2022-11-18
# Data extraída: 20221128
# Nova busca a partir de 2022-11-29
# Data extraída: 20221208
# Nova busca a partir de 2022-12-09
# Data extraída: 20221218
# Nova busca a partir de 2022-12-19
# Data extraída: 20221228
# Nova busca a partir de 2022-12-29
# Data extraída: 20230107
# Nova busca a partir de 2023-01-08
# Data extraída: 20230118
# Nova busca a partir de 2023-01-19
# Data extraída: 20230129
# Nova busca a partir de 2023-01-30
# Data extraída: 20230209
# Nova busca a partir de 2023-02-10
# Data extraída: 20230219
# Nova busca a partir de 2023-02-20
# Data extraída: 20230301
# Nova busca a partir de 2023-03-02
# Data extraída: 20230312
# Nova busca a partir de 2023-03-13
# Data extraída: 20230322
# Nova busca a partir de 2023-03-23
# Data extraída: 20230401
# Nova busca a partir de 2023-04-02
# Data extraída: 20230412
# Nova busca a partir de 2023-04-13
# Data extraída: 20230422
# Nova busca a partir de 2023-04-23
# Data extraída: 20230502
# Nova busca a partir de 2023-05-03
# Data extraída: 20230512
# Nova busca a partir de 2023-05-13
# Data extraída: 20230522
# Nova busca a partir de 2023-05-23
# Data extraída: 20230601
# Nova busca a partir de 2023-06-02
# Data extraída: 20230611
# Nova busca a partir de 2023-06-12
# Data extraída: 20230621
# Nova busca a partir de 2023-06-22
# Data extraída: 20230702
# Nova busca a partir de 2023-07-03
# Data extraída: 20230712
# Nova busca a partir de 2023-07-13
# Data extraída: 20230722
# Nova busca a partir de 2023-07-23
# Data extraída: 20230801
# Nova busca a partir de 2023-08-02
# Data extraída: 20230811
# Nova busca a partir de 2023-08-12
# Data extraída: 20230822
# Nova busca a partir de 2023-08-23
# Data extraída: 20230902
# Nova busca a partir de 2023-09-03
# Data extraída: 20230913
# Nova busca a partir de 2023-09-14
# Data extraída: 20230923
# Nova busca a partir de 2023-09-24
# Data extraída: 20231003
# Nova busca a partir de 2023-10-04
# Data extraída: 20231014
# Nova busca a partir de 2023-10-15
# Data extraída: 20231024
# Nova busca a partir de 2023-10-25
# Data extraída: 20231103
# Nova busca a partir de 2023-11-04
# Data extraída: 20231114
# Nova busca a partir de 2023-11-15
# Data extraída: 20231124
# Nova busca a partir de 2023-11-25
# Data extraída: 20231204
# Nova busca a partir de 2023-12-05
# Data extraída: 20231214
# Nova busca a partir de 2023-12-15
# Data extraída: 20231224
# Nova busca a partir de 2023-12-25
# Data extraída: 20240104
# Nova busca a partir de 2024-01-05
# Data extraída: 20240115
# Nova busca a partir de 2024-01-16
# Data extraída: 20240127
# Nova busca a partir de 2024-01-28
# Data extraída: 20240206
# Nova busca a partir de 2024-02-07
# Data extraída: 20240216
# Nova busca a partir de 2024-02-17
# Data extraída: 20240227
# Nova busca a partir de 2024-02-28
# Data extraída: 20240309
# Nova busca a partir de 2024-03-10
# Data extraída: 20240320
# Nova busca a partir de 2024-03-21
# Data extraída: 20240330
# Nova busca a partir de 2024-03-31
# Data extraída: 20240409
# Nova busca a partir de 2024-04-10
# Data extraída: 20240420
# Nova busca a partir de 2024-04-21
# Data extraída: 20240430
# Nova busca a partir de 2024-05-01
# Data extraída: 20240510
# Nova busca a partir de 2024-05-11
# Data extraída: 20240521
# Nova busca a partir de 2024-05-22
# Data extraída: 20240531
# Nova busca a partir de 2024-06-01
# Data extraída: 20240610
# Nova busca a partir de 2024-06-11
# Data extraída: 20240620
# Nova busca a partir de 2024-06-21
# Data extraída: 20240630
# Nova busca a partir de 2024-07-01
# Data extraída: 20240711
# Nova busca a partir de 2024-07-12
# Data extraída: 20240722
# Nova busca a partir de 2024-07-23
# Data extraída: 20240802
# Nova busca a partir de 2024-08-03
# Data extraída: 20240812
# Nova busca a partir de 2024-08-13
# Data extraída: 20240822
# Nova busca a partir de 2024-08-23
# Data extraída: 20240902
# Nova busca a partir de 2024-09-03
# Data extraída: 20240912
# Nova busca a partir de 2024-09-13
# Data extraída: 20240922
# Nova busca a partir de 2024-09-23
# Data extraída: 20241003
# Nova busca a partir de 2024-10-04
# Data extraída: 20241013
# Nova busca a partir de 2024-10-14
# Data extraída: 20241023
# Nova busca a partir de 2024-10-24
# Data extraída: 20241102
# Nova busca a partir de 2024-11-03
# Data extraída: 20241112
# Nova busca a partir de 2024-11-13
# Data extraída: 20241123
# Nova busca a partir de 2024-11-24
# Data extraída: 20241204
# Nova busca a partir de 2024-12-05
# Data extraída: 20241215
# Nova busca a partir de 2024-12-16
# Data extraída: 20241225
# Nova busca a partir de 2024-12-26
# Data extraída: 20241231
# Nova busca a partir de 2025-01-01
# Total de produtos encontrados: 5872

# %% [markdown]
# 4. Realizando download das imagens encontradas. Obs: defina o diretório para onde você deseja descarregar as imagens. ATTENZIONNE: É NECESSÁRIO CRIAR UM LOGIN E SENHA EM: https://browser.dataspace.copernicus.eu/

# %%
#Escreva abaixo o seu login-senha do copernicus browser
user = 'username'
password = 'password'

#Abaixo defina o diretório em que você deseja descarregar as imagens (por padrão vou deixar a própria pasta onde está o código, mas isso não é recomendável
download_directory = '.'

#Código de download
def get_access_token(username, password):
    data = {
        "client_id": "cdse-public",
        "username": username,
        "password": password,
        "grant_type": "password",
    }
    try:
        r = requests.post(
            "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token",
            data=data,
        )
        r.raise_for_status()
    except Exception as e:
        raise Exception(
            f"Access token creation failed. Response from the server was: {r.json()}"
        )
    return r.json()["access_token"]

def download_copernicus_product(access_token, name_file, output_directory=".", output_name=None):
    from tqdm import tqdm
    extent_file = {'S2': 'SAFE', 'S3': 'SEN3'}

    json_data = requests.get(
        f"https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=Name eq '{name_file}'"
    ).json()

    id_product = pd.DataFrame.from_dict(json_data["value"]).head(1)["Id"][0]

    url = f"https://zipper.dataspace.copernicus.eu/odata/v1/Products({id_product})/$value"

    headers = {"Authorization": f"Bearer {access_token}"}

    session = requests.Session()
    session.headers.update(headers)
    response = session.get(url, headers=headers, stream=True)

    file_size = int(response.headers.get("content-length", 0))
    block_size = 1024

    output_name = output_name or f"{name_file}.zip"
    output_path = os.path.join(output_directory, output_name)

    with open(output_path, "wb") as file, tqdm(
        desc="Downloading",
        total=file_size,
        unit="B",
        unit_scale=True,
        unit_divisor=1024,
        bar_format="{desc}: {percentage:3.0f}%|{bar}| {n_fmt}/{total_fmt} {unit}",
        dynamic_ncols=True,
        colour="BLUE",
        leave=False,
    ) as bar:
        for chunk in response.iter_content(chunk_size=block_size):
            if chunk:
                file.write(chunk)
                bar.update(len(chunk))

path_list_zip = os.listdir(download_directory)
files_zip = [arquivo[:-4] for arquivo in path_list_zip if arquivo.endswith('.zip')]

download_count = 0

for name_file in all_results:
    name_file = name_file+'.SEN3'

    if name_file in files_zip:
        print(f"{name_file} já foi baixado anteriormente")
        continue  # pula os produtos já baixados

    if download_count == len(result_df):
        # Reinicia a sessão do Google Colab após 4 downloads
        print(f"Encerrando sessão após baixar {len(all_results)} produtos...")
        #download_count = 0
        break

    try:
        access_token = get_access_token(user, password)
        print(name_file)
        download_copernicus_product(access_token, name_file, download_directory)
        download_count += 1

    except Exception as e:
        print(f"{name_file} falhou no download: {e}")
        # Exclui o arquivo que estava sendo baixado em caso de erro
        file_path = f"./l1_scenes/{name_file}.zip"
        if os.path.exists(file_path):
            try:
                os.remove(file_path)
                print(f"Arquivo {file_path} excluído devido a erro no download.")
            except Exception as delete_error:
                print(f"Falha ao tentar excluir {file_path}: {delete_error}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 from tqdm import tqdm
#       6 import sys
# ----> 8 result_df = pd.read_csv("list_scene_s3.csv")
#       9 result_df = result_df.drop_duplicates('id_scene').reset_index(drop=True)
#      10 print(len(result_df))
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'list_scene_s3.csv'
